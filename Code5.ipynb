# %%
# Function to calculate sample size
def calculate_sample_size(population_size, confidence_level, margin_of_error):
    if confidence_level == 90:
        z_score = 1.64
    elif confidence_level == 95:
        z_score = 1.96
    elif confidence_level == 99:
        z_score = 2.58
    else:
        print("Unsupported confidence level. Please input a value of 90, 95, or 99")
        return None
    
    # Specify unknown proportion value
    p = 0.5
    
    # Perform the calculation
    sample_size = ((z_score * z_score * p * (1-p))/(margin_of_error * margin_of_error))
    return int(sample_size)

# Function for systematic sampling
def systematic_sample(population, sample_size):
    interval = len(population) / sample_size
    interval = round(interval)
    
    selected_elements = []
    
    for j in range(0, len(population), interval):
        selected_elements.append(population[j])
        
    return selected_elements

# Getting user input
population_size = int(input("Enter the population size: "))
confidence_level = int(input("Enter the confidence level, for example 90, 95, or 99: "))
margin_of_error = float(input("Enter the desired margin of error, for example 0.05, 0.10: "))
                        
sample_size = calculate_sample_size(population_size, confidence_level, margin_of_error)
                        
print(f"The calculated sample size was approximately {sample_size} ")

user_sample_size = int(input("Enter your desired sample size: "))

maximum_sample_size = calculate_sample_size(population_size, 99, 0.01)

if user_sample_size > maximum_sample_size:
    print("Sorry, the requested sample size is likely not feasible. Please enter a lower value.")
else: 
    systematic_sample_result = systematic_sample(list(range(1, population_size + 1)), sample_size)
    
    print("The following elements were selected by systematic random sampling: ")
    print(systematic_sample_result)
# Out:
# Enter the population size:  168000
# Enter the confidence level, for example 90, 95, or 99:  99
# Enter the desired margin of error, for example 0.05, 0.10:  0.05
# The calculated sample size was approximately 665
# Enter your desired sample size:  10000
# The following elements were selected by systematic random sampling:
# [1, 254, 507, 760, 1013, 1266, 1519, 1772, 2025, 2278, 2531, 2784, 3037, 3290, 3543, 3796, 4049, 4302, 4555, 4808, 5061, 5314, 5567, 5820, 6073, 6326, 6579, 6832, 7085, 7338, 7591, 7844, 8097, 8350, 8603, 8856, 9109, 9362, 9615, 9868, 10121, 10374, 10627, 10880, 11133, 11386, 11639, 11892, 12145, 12398, 12651, 12904, 13157, 13410, 13663, 13916, 14169, 14422, 14675, 14928, 15181, 15434, 15687, 15940, 16193, 16446, 16699, 16952, 17205, 17458, 17711, 17964, 18217, 18470, 18723, 18976, 19229, 19482, 19735, 19988, 20241, 20494, 20747, 21000, 21253, 21506, 21759, 22012, 22265, 22518, 22771, 23024, 23277, 23530, 23783, 24036, 24289, 24542, 24795, 25048, 25301, 25554, 25807, 26060, 26313, 26566, 26819, 27072, 27325, 27578, 27831, 28084, 28337, 28590, 28843, 29096, 29349, 29602, 29855, 30108, 30361, 30614, 30867, 31120, 31373, 31626, 31879, 32132, 32385, 32638, 32891, 33144, 33397, 33650, 33903, 34156, 34409, 34662, 34915, 35168, 35421, 35674, 35927, 36180, 36433, 36686, 36939, 37192, 37445, 37698, 37951, 38204, 38457, 38710, 38963, 39216, 39469, 39722, 39975, 40228, 40481, 40734, 40987, 41240, 41493, 41746, 41999, 42252, 42505, 42758, 43011, 43264, 43517, 43770, 44023, 44276, 44529, 44782, 45035